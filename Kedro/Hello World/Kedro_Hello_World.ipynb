# %%
# !pip install kedro
# Out:
# Collecting kedro
#   Downloading kedro-0.17.6-py3-none-any.whl (24.8 MB)
#      |████████████████████████████████| 24.8 MB 1.6 MB/s
# Requirement already satisfied: jupyter-client<7.0,>=5.1 in /usr/local/lib/python3.7/dist-packages (from kedro) (5.3.5)
# Collecting jmespath<1.0,>=0.9.5
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: cachetools~=4.1 in /usr/local/lib/python3.7/dist-packages (from kedro) (4.2.4)
# Collecting rope~=0.21.0
#   Downloading rope-0.21.1-py3-none-any.whl (185 kB)
#      |████████████████████████████████| 185 kB 55.8 MB/s
# Collecting PyYAML<6.0,>=4.2
#   Downloading PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
#      |████████████████████████████████| 636 kB 52.4 MB/s
# Collecting gitpython~=3.0
#   Downloading GitPython-3.1.26-py3-none-any.whl (180 kB)
#      |████████████████████████████████| 180 kB 67.7 MB/s
# Collecting pip-tools~=6.4
#   Downloading pip_tools-6.4.0-py3-none-any.whl (47 kB)
#      |████████████████████████████████| 47 kB 4.5 MB/s
# Requirement already satisfied: setuptools>=38.0 in /usr/local/lib/python3.7/dist-packages (from kedro) (57.4.0)
# Requirement already satisfied: toml~=0.10 in /usr/local/lib/python3.7/dist-packages (from kedro) (0.10.2)
# Collecting cookiecutter~=1.7.0
#   Downloading cookiecutter-1.7.3-py2.py3-none-any.whl (34 kB)
# Collecting fsspec<2022.01,>=2021.04
#   Downloading fsspec-2021.11.1-py3-none-any.whl (132 kB)
#      |████████████████████████████████| 132 kB 50.4 MB/s
# Collecting pluggy~=0.13.0
#   Downloading pluggy-0.13.1-py2.py3-none-any.whl (18 kB)
# Collecting anyconfig~=0.10.0
#   Downloading anyconfig-0.10.1-py2.py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 2.9 MB/s
# Collecting dynaconf<4.0.0,>=3.1.2
#   Downloading dynaconf-3.1.7-py2.py3-none-any.whl (200 kB)
#      |████████████████████████████████| 200 kB 58.8 MB/s
# Collecting toposort~=1.5
#   Downloading toposort-1.7-py2.py3-none-any.whl (9.0 kB)
# Collecting python-json-logger~=2.0
#   Downloading python_json_logger-2.0.2-py3-none-any.whl (7.4 kB)
# Requirement already satisfied: click<8.0 in /usr/local/lib/python3.7/dist-packages (from kedro) (7.1.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.7/dist-packages (from cookiecutter~=1.7.0->kedro) (2.23.0)
# Collecting poyo>=0.5.0
#   Downloading poyo-0.5.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from cookiecutter~=1.7.0->kedro) (1.15.0)
# Requirement already satisfied: Jinja2<4.0.0,>=2.7 in /usr/local/lib/python3.7/dist-packages (from cookiecutter~=1.7.0->kedro) (2.11.3)
# Collecting jinja2-time>=0.2.0
#   Downloading jinja2_time-0.2.0-py2.py3-none-any.whl (6.4 kB)
# Requirement already satisfied: python-slugify>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from cookiecutter~=1.7.0->kedro) (5.0.2)
# Collecting binaryornot>=0.4.4
#   Downloading binaryornot-0.4.4-py2.py3-none-any.whl (9.0 kB)
# Requirement already satisfied: chardet>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from binaryornot>=0.4.4->cookiecutter~=1.7.0->kedro) (3.0.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from gitpython~=3.0->kedro) (3.10.0.2)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 1.6 MB/s
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2<4.0.0,>=2.7->cookiecutter~=1.7.0->kedro) (2.0.1)
# Collecting arrow
#   Downloading arrow-1.2.2-py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 2.8 MB/s
# Requirement already satisfied: tornado>=4.1 in /usr/local/lib/python3.7/dist-packages (from jupyter-client<7.0,>=5.1->kedro) (5.1.1)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.7/dist-packages (from jupyter-client<7.0,>=5.1->kedro) (2.8.2)
# Requirement already satisfied: jupyter-core>=4.6.0 in /usr/local/lib/python3.7/dist-packages (from jupyter-client<7.0,>=5.1->kedro) (4.9.1)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.7/dist-packages (from jupyter-client<7.0,>=5.1->kedro) (22.3.0)
# Requirement already satisfied: traitlets in /usr/local/lib/python3.7/dist-packages (from jupyter-client<7.0,>=5.1->kedro) (5.1.1)
# Collecting pip>=21.2
#   Downloading pip-22.0.2-py3-none-any.whl (2.1 MB)
#      |████████████████████████████████| 2.1 MB 42.0 MB/s
# Requirement already satisfied: pep517 in /usr/local/lib/python3.7/dist-packages (from pip-tools~=6.4->kedro) (0.12.0)
# Requirement already satisfied: wheel in /usr/local/lib/python3.7/dist-packages (from pip-tools~=6.4->kedro) (0.37.1)
# Requirement already satisfied: importlib-metadata>=0.12 in /usr/local/lib/python3.7/dist-packages (from pluggy~=0.13.0->kedro) (4.10.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.12->pluggy~=0.13.0->kedro) (3.7.0)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify>=4.0.0->cookiecutter~=1.7.0->kedro) (1.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.23.0->cookiecutter~=1.7.0->kedro) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.23.0->cookiecutter~=1.7.0->kedro) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.23.0->cookiecutter~=1.7.0->kedro) (2021.10.8)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from pep517->pip-tools~=6.4->kedro) (2.0.0)
# Installing collected packages: smmap, arrow, poyo, pip, jinja2-time, gitdb, binaryornot, toposort, rope, PyYAML, python-json-logger, pluggy, pip-tools, jmespath, gitpython, fsspec, dynaconf, cookiecutter, anyconfig, kedro
#   Attempting uninstall: pip
#     Found existing installation: pip 21.1.3
#     Uninstalling pip-21.1.3:
#       Successfully uninstalled pip-21.1.3
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: pluggy
#     Found existing installation: pluggy 0.7.1
#     Uninstalling pluggy-0.7.1:
#       Successfully uninstalled pluggy-0.7.1
#   Attempting uninstall: pip-tools
#     Found existing installation: pip-tools 6.2.0
#     Uninstalling pip-tools-6.2.0:
#       Successfully uninstalled pip-tools-6.2.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pytest 3.6.4 requires pluggy<0.8,>=0.5, but you have pluggy 0.13.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed PyYAML-5.4.1 anyconfig-0.10.1 arrow-1.2.2 binaryornot-0.4.4 cookiecutter-1.7.3 dynaconf-3.1.7 fsspec-2021.11.1 gitdb-4.0.9 gitpython-3.1.26 jinja2-time-0.2.0 jmespath-0.10.0 kedro-0.17.6 pip-22.0.2 pip-tools-6.4.0 pluggy-0.13.1 poyo-0.5.0 python-json-logger-2.0.2 rope-0.21.1 smmap-5.0.0 toposort-1.7

# %%
"""Contents of hello_kedro.py"""
from kedro.io import DataCatalog, MemoryDataSet
from kedro.pipeline import node, Pipeline
from kedro.runner import SequentialRunner

# Prepare a data catalog
data_catalog = DataCatalog({"my_salutation": MemoryDataSet()})

# Prepare first node
def return_greeting():
    return "Hello"


return_greeting_node = node(return_greeting, inputs=None, outputs="my_salutation")

# Prepare second node
def join_statements(greeting):
    return f"{greeting} Kedro!"


join_statements_node = node(
    join_statements, inputs="my_salutation", outputs="my_message"
)

# Assemble nodes into a pipeline
pipeline = Pipeline([return_greeting_node, join_statements_node])

# Create a runner to run the pipeline
runner = SequentialRunner()

# Run the pipeline
print(runner.run(pipeline, data_catalog))
# Out:
# {'my_message': 'Hello Kedro!'}
# /usr/local/lib/python3.7/dist-packages/kedro/io/data_catalog.py:194: DeprecationWarning: The transformer API will be deprecated in Kedro 0.18.0.Please use Dataset Hooks to customise the load and save methods.For more information, please visithttps://kedro.readthedocs.io/en/stable/07_extend_kedro/02_hooks.html
#   DeprecationWarning,
